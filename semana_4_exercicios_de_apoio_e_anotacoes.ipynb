# %% [markdown]
# #Anotações das aulas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#histograma (distribuição) que gera 30 valores (sendo 1 por dia) com minutos de 0 a 60
minutos = np.random.randint(0,60,30)

# %%
minutos
# Out:
# array([50, 42, 29,  7, 17, 19,  6,  2, 56, 17, 50, 17, 32,  9,  8, 26, 49,
#        31, 59, 32, 11, 53, 44,  0, 59,  8, 33, 48, 11, 15])

# %%
import seaborn as sns
ax = sns.histplot(data=minutos)
ax.set(xlabel='Minutos Por Dia', ylabel='Quantidade de Vezes')
plt.show()

# %%
arquivo ='https://raw.githubusercontent.com/JeffSackmann/tennis_atp/master/atp_matches_2021.csv' #arquivo que contem dados dos jogos de tenis em 2021

# %%
dados = pd.read_csv(arquivo)
dados.head(5)
# Out:
#   tourney_id  tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  2021-0499  Delray Beach    Hard         32             A      20210104
# 1  2021-0499  Delray Beach    Hard         32             A      20210104
# 2  2021-0499  Delray Beach    Hard         32             A      20210104
# 3  2021-0499  Delray Beach    Hard         32             A      20210104
# 4  2021-0499  Delray Beach    Hard         32             A      20210104
#
#    match_num  winner_id  winner_seed winner_entry  ... l_1stIn l_1stWon  \
# 0        300     128034          4.0          NaN  ...    33.0     20.0
# 1        299     128034          4.0          NaN  ...    46.0     29.0
# 2        298     200624          NaN          NaN  ...    35.0     25.0
# 3        297     106328          NaN            Q  ...    45.0     34.0
# 4        296     128034          4.0          NaN  ...    43.0     28.0
#
#    l_2ndWon l_SvGms  l_bpSaved  l_bpFaced  winner_rank winner_rank_points  \
# 0       9.0     9.0        1.0        5.0         35.0             1518.0
# 1      13.0    11.0        3.0        5.0         35.0             1518.0
# 2       7.0    10.0        2.0        6.0        119.0              566.0
# 3      18.0    11.0        9.0       11.0        789.0               22.0
# 4      10.0    10.0        7.0       10.0         35.0             1518.0
#
#   loser_rank loser_rank_points
# 0      119.0             566.0
# 1      789.0              22.0
# 2       74.0             877.0
# 3      101.0             733.0
# 4      293.0             171.0
#
# [5 rows x 49 columns]

# %%
dados.info
# Out:
# <bound method DataFrame.info of                            tourney_id                  tourney_name surface  \
# 0                           2021-0499                  Delray Beach    Hard
# 1                           2021-0499                  Delray Beach    Hard
# 2                           2021-0499                  Delray Beach    Hard
# 3                           2021-0499                  Delray Beach    Hard
# 4                           2021-0499                  Delray Beach    Hard
# ...                               ...                           ...     ...
# 2722  2021-M-DC-2021-WG2-M-THA-DEN-01  Davis Cup WG2 R1: THA vs DEN    Hard
# 2723  2021-M-DC-2021-WG2-M-THA-DEN-01  Davis Cup WG2 R1: THA vs DEN    Hard
# 2724  2021-M-DC-2021-WG2-M-TUR-LAT-01  Davis Cup WG2 R1: TUR vs LAT    Hard
# 2725  2021-M-DC-2021-WG2-M-TUR-LAT-01  Davis Cup WG2 R1: TUR vs LAT    Hard
# 2726  2021-M-DC-2021-WG2-M-TUR-LAT-01  Davis Cup WG2 R1: TUR vs LAT    Hard
#
#       draw_size tourney_level  tourney_date  match_num  winner_id  \
# 0            32             A      20210104        300     128034
# 1            32             A      20210104        299     128034
# 2            32             A      20210104        298     200624
# 3            32             A      20210104        297     106328
# 4            32             A      20210104        296     128034
# ...         ...           ...           ...        ...        ...
# 2722          4             D      20210917          4     200416
# 2723          4             D      20210917          5     208937
# 2724          4             D      20210918          1     123795
# 2725          4             D      20210918          2     117356
# 2726          4             D      20210918          4     144985
#
#       winner_seed winner_entry  ... l_1stIn l_1stWon  l_2ndWon l_SvGms  \
# 0             4.0          NaN  ...    33.0     20.0       9.0     9.0
# 1             4.0          NaN  ...    46.0     29.0      13.0    11.0
# 2             NaN          NaN  ...    35.0     25.0       7.0    10.0
# 3             NaN            Q  ...    45.0     34.0      18.0    11.0
# 4             4.0          NaN  ...    43.0     28.0      10.0    10.0
# ...           ...          ...  ...     ...      ...       ...     ...
# 2722          NaN          NaN  ...    45.0     30.0      14.0    10.0
# 2723          NaN          NaN  ...    43.0     24.0      13.0    10.0
# 2724          NaN          NaN  ...    50.0     34.0      20.0    11.0
# 2725          NaN          NaN  ...    21.0     16.0       7.0     8.0
# 2726          NaN          NaN  ...    34.0     17.0       7.0     7.0
#
#       l_bpSaved  l_bpFaced  winner_rank winner_rank_points loser_rank  \
# 0           1.0        5.0         35.0             1518.0      119.0
# 1           3.0        5.0         35.0             1518.0      789.0
# 2           2.0        6.0        119.0              566.0       74.0
# 3           9.0       11.0        789.0               22.0      101.0
# 4           7.0       10.0         35.0             1518.0      293.0
# ...         ...        ...          ...                ...        ...
# 2722       10.0       13.0        905.0               16.0      767.0
# 2723        5.0       11.0       1136.0                8.0     1546.0
# 2724        6.0        9.0        170.0              427.0      671.0
# 2725        2.0        7.0        176.0              408.0      196.0
# 2726        3.0        7.0        311.0              166.0        NaN
#
#      loser_rank_points
# 0                566.0
# 1                 22.0
# 2                877.0
# 3                733.0
# 4                171.0
# ...                ...
# 2722              27.0
# 2723               2.0
# 2724              38.0
# 2725             359.0
# 2726               NaN
#
# [2727 rows x 49 columns]>

# %%
dados.describe(include='all')
# Out:
#        tourney_id     tourney_name surface   draw_size tourney_level  \
# count        2727             2727    2727  2727.00000          2727
# unique        113              113       3         NaN             5
# top      2021-580  Australian Open    Hard         NaN             A
# freq          127              127    1602         NaN          1563
# mean          NaN              NaN     NaN    62.72974           NaN
# std           NaN              NaN     NaN    41.48827           NaN
# min           NaN              NaN     NaN     2.00000           NaN
# 25%           NaN              NaN     NaN    32.00000           NaN
# 50%           NaN              NaN     NaN    64.00000           NaN
# 75%           NaN              NaN     NaN   128.00000           NaN
# max           NaN              NaN     NaN   128.00000           NaN
#
#         tourney_date    match_num      winner_id  winner_seed winner_entry  \
# count   2.727000e+03  2727.000000    2727.000000  1165.000000          417
# unique           NaN          NaN            NaN          NaN            6
# top              NaN          NaN            NaN          NaN            Q
# freq             NaN          NaN            NaN          NaN          234
# mean    2.021060e+07   243.556289  127554.860653     7.687554          NaN
# std     2.854694e+02    73.704779   33996.043979     7.133621          NaN
# min     2.021010e+07     1.000000  100644.000000     1.000000          NaN
# 25%     2.021032e+07   225.000000  105575.000000     3.000000          NaN
# 50%     2.021061e+07   276.000000  106432.000000     6.000000          NaN
# 75%     2.021082e+07   289.000000  128034.000000    10.000000          NaN
# max     2.021120e+07   300.000000  210107.000000    32.000000          NaN
#
#         ...      l_1stIn     l_1stWon     l_2ndWon      l_SvGms    l_bpSaved  \
# count   ...  2636.000000  2636.000000  2636.000000  2637.000000  2636.000000
# unique  ...          NaN          NaN          NaN          NaN          NaN
# top     ...          NaN          NaN          NaN          NaN          NaN
# freq    ...          NaN          NaN          NaN          NaN          NaN
# mean    ...    50.118361    33.325493    14.494689    12.420554     4.843323
# std     ...    19.075552    14.205041     6.857036     4.224477     3.253624
# min     ...     2.000000     0.000000     0.000000     0.000000     0.000000
# 25%     ...    36.000000    23.000000    10.000000     9.000000     2.000000
# 50%     ...    47.000000    31.000000    14.000000    11.000000     4.000000
# 75%     ...    61.000000    42.000000    18.000000    15.000000     7.000000
# max     ...   165.000000   104.000000    48.000000    31.000000    27.000000
#
#           l_bpFaced  winner_rank winner_rank_points   loser_rank  \
# count   2636.000000  2722.000000        2722.000000  2701.000000
# unique          NaN          NaN                NaN          NaN
# top             NaN          NaN                NaN          NaN
# freq            NaN          NaN                NaN          NaN
# mean       8.714719    70.638501        2220.377663   103.198815
# std        4.126347   102.984587        2475.604724   149.243436
# min        0.000000     1.000000           1.000000     1.000000
# 25%        6.000000    20.000000         855.750000    37.000000
# 50%        8.000000    47.000000        1344.000000    68.000000
# 75%       11.000000    87.000000        2418.000000   112.000000
# max       38.000000  1758.000000       12113.000000  2146.000000
#
#        loser_rank_points
# count        2701.000000
# unique               NaN
# top                  NaN
# freq                 NaN
# mean         1388.586449
# std          1460.176805
# min             1.000000
# 25%           707.000000
# 50%           992.000000
# 75%          1591.000000
# max         12113.000000
#
# [11 rows x 49 columns]

# %%
dados.isnull()
# Out:
#       tourney_id  tourney_name  surface  draw_size  tourney_level  \
# 0          False         False    False      False          False
# 1          False         False    False      False          False
# 2          False         False    False      False          False
# 3          False         False    False      False          False
# 4          False         False    False      False          False
# ...          ...           ...      ...        ...            ...
# 2722       False         False    False      False          False
# 2723       False         False    False      False          False
# 2724       False         False    False      False          False
# 2725       False         False    False      False          False
# 2726       False         False    False      False          False
#
#       tourney_date  match_num  winner_id  winner_seed  winner_entry  ...  \
# 0            False      False      False        False          True  ...
# 1            False      False      False        False          True  ...
# 2            False      False      False         True          True  ...
# 3            False      False      False         True         False  ...
# 4            False      False      False        False          True  ...
# ...            ...        ...        ...          ...           ...  ...
# 2722         False      False      False         True          True  ...
# 2723         False      False      False         True          True  ...
# 2724         False      False      False         True          True  ...
# 2725         False      False      False         True          True  ...
# 2726         False      False      False         True          True  ...
#
#       l_1stIn  l_1stWon  l_2ndWon  l_SvGms  l_bpSaved  l_bpFaced  winner_rank  \
# 0       False     False     False    False      False      False        False
# 1       False     False     False    False      False      False        False
# 2       False     False     False    False      False      False        False
# 3       False     False     False    False      False      False        False
# 4       False     False     False    False      False      False        False
# ...       ...       ...       ...      ...        ...        ...          ...
# 2722    False     False     False    False      False      False        False
# 2723    False     False     False    False      False      False        False
# 2724    False     False     False    False      False      False        False
# 2725    False     False     False    False      False      False        False
# 2726    False     False     False    False      False      False        False
#
#       winner_rank_points  loser_rank  loser_rank_points
# 0                  False       False              False
# 1                  False       False              False
# 2                  False       False              False
# 3                  False       False              False
# 4                  False       False              False
# ...                  ...         ...                ...
# 2722               False       False              False
# 2723               False       False              False
# 2724               False       False              False
# 2725               False       False              False
# 2726               False        True               True
#
# [2727 rows x 49 columns]

# %%
dados.isnull().sum() #checando dados nulos nas colunas
# Out:
# tourney_id               0
# tourney_name             0
# surface                  0
# draw_size                0
# tourney_level            0
# tourney_date             0
# match_num                0
# winner_id                0
# winner_seed           1562
# winner_entry          2310
# winner_name              0
# winner_hand              2
# winner_ht              338
# winner_ioc               0
# winner_age               0
# loser_id                 0
# loser_seed            2034
# loser_entry           2092
# loser_name               0
# loser_hand               0
# loser_ht               523
# loser_ioc                0
# loser_age                2
# score                    0
# best_of                  0
# round                    0
# minutes                 77
# w_ace                   91
# w_df                    91
# w_svpt                  91
# w_1stIn                 91
# w_1stWon                91
# w_2ndWon                91
# w_SvGms                 90
# w_bpSaved               91
# w_bpFaced               91
# l_ace                   91
# l_df                    91
# l_svpt                  91
# l_1stIn                 91
# l_1stWon                91
# l_2ndWon                91
# l_SvGms                 90
# l_bpSaved               91
# l_bpFaced               91
# winner_rank              5
# winner_rank_points       5
# loser_rank              26
# loser_rank_points       26
# dtype: int64

# %%
#Apagar todas as linhas que o atributo "loser_rank" é nulo, porque são poucas ocasioes e isso pode implicar erros nos resultados
dados.dropna(subset=['loser_rank'], inplace=True)

# %%
dados
# Out:
#                            tourney_id                  tourney_name surface  \
# 0                           2021-0499                  Delray Beach    Hard
# 1                           2021-0499                  Delray Beach    Hard
# 2                           2021-0499                  Delray Beach    Hard
# 3                           2021-0499                  Delray Beach    Hard
# 4                           2021-0499                  Delray Beach    Hard
# ...                               ...                           ...     ...
# 2721  2021-M-DC-2021-WG2-M-THA-DEN-01  Davis Cup WG2 R1: THA vs DEN    Hard
# 2722  2021-M-DC-2021-WG2-M-THA-DEN-01  Davis Cup WG2 R1: THA vs DEN    Hard
# 2723  2021-M-DC-2021-WG2-M-THA-DEN-01  Davis Cup WG2 R1: THA vs DEN    Hard
# 2724  2021-M-DC-2021-WG2-M-TUR-LAT-01  Davis Cup WG2 R1: TUR vs LAT    Hard
# 2725  2021-M-DC-2021-WG2-M-TUR-LAT-01  Davis Cup WG2 R1: TUR vs LAT    Hard
#
#       draw_size tourney_level  tourney_date  match_num  winner_id  \
# 0            32             A      20210104        300     128034
# 1            32             A      20210104        299     128034
# 2            32             A      20210104        298     200624
# 3            32             A      20210104        297     106328
# 4            32             A      20210104        296     128034
# ...         ...           ...           ...        ...        ...
# 2721          4             D      20210917          2     200416
# 2722          4             D      20210917          4     200416
# 2723          4             D      20210917          5     208937
# 2724          4             D      20210918          1     123795
# 2725          4             D      20210918          2     117356
#
#       winner_seed winner_entry  ... l_1stIn l_1stWon  l_2ndWon l_SvGms  \
# 0             4.0          NaN  ...    33.0     20.0       9.0     9.0
# 1             4.0          NaN  ...    46.0     29.0      13.0    11.0
# 2             NaN          NaN  ...    35.0     25.0       7.0    10.0
# 3             NaN            Q  ...    45.0     34.0      18.0    11.0
# 4             4.0          NaN  ...    43.0     28.0      10.0    10.0
# ...           ...          ...  ...     ...      ...       ...     ...
# 2721          NaN          NaN  ...    57.0     38.0      15.0    14.0
# 2722          NaN          NaN  ...    45.0     30.0      14.0    10.0
# 2723          NaN          NaN  ...    43.0     24.0      13.0    10.0
# 2724          NaN          NaN  ...    50.0     34.0      20.0    11.0
# 2725          NaN          NaN  ...    21.0     16.0       7.0     8.0
#
#       l_bpSaved  l_bpFaced  winner_rank winner_rank_points loser_rank  \
# 0           1.0        5.0         35.0             1518.0      119.0
# 1           3.0        5.0         35.0             1518.0      789.0
# 2           2.0        6.0        119.0              566.0       74.0
# 3           9.0       11.0        789.0               22.0      101.0
# 4           7.0       10.0         35.0             1518.0      293.0
# ...         ...        ...          ...                ...        ...
# 2721        5.0       11.0        905.0               16.0     1136.0
# 2722       10.0       13.0        905.0               16.0      767.0
# 2723        5.0       11.0       1136.0                8.0     1546.0
# 2724        6.0        9.0        170.0              427.0      671.0
# 2725        2.0        7.0        176.0              408.0      196.0
#
#      loser_rank_points
# 0                566.0
# 1                 22.0
# 2                877.0
# 3                733.0
# 4                171.0
# ...                ...
# 2721               8.0
# 2722              27.0
# 2723               2.0
# 2724              38.0
# 2725             359.0
#
# [2701 rows x 49 columns]

# %%
#apagar todas as coluna que apresentam resultados nulos
dados.dropna(axis=1, how= 'all')
# Out:
#                            tourney_id                  tourney_name surface  \
# 0                           2021-0499                  Delray Beach    Hard
# 1                           2021-0499                  Delray Beach    Hard
# 2                           2021-0499                  Delray Beach    Hard
# 3                           2021-0499                  Delray Beach    Hard
# 4                           2021-0499                  Delray Beach    Hard
# ...                               ...                           ...     ...
# 2721  2021-M-DC-2021-WG2-M-THA-DEN-01  Davis Cup WG2 R1: THA vs DEN    Hard
# 2722  2021-M-DC-2021-WG2-M-THA-DEN-01  Davis Cup WG2 R1: THA vs DEN    Hard
# 2723  2021-M-DC-2021-WG2-M-THA-DEN-01  Davis Cup WG2 R1: THA vs DEN    Hard
# 2724  2021-M-DC-2021-WG2-M-TUR-LAT-01  Davis Cup WG2 R1: TUR vs LAT    Hard
# 2725  2021-M-DC-2021-WG2-M-TUR-LAT-01  Davis Cup WG2 R1: TUR vs LAT    Hard
#
#       draw_size tourney_level  tourney_date  match_num  winner_id  \
# 0            32             A      20210104        300     128034
# 1            32             A      20210104        299     128034
# 2            32             A      20210104        298     200624
# 3            32             A      20210104        297     106328
# 4            32             A      20210104        296     128034
# ...         ...           ...           ...        ...        ...
# 2721          4             D      20210917          2     200416
# 2722          4             D      20210917          4     200416
# 2723          4             D      20210917          5     208937
# 2724          4             D      20210918          1     123795
# 2725          4             D      20210918          2     117356
#
#       winner_seed winner_entry  ... l_1stIn l_1stWon  l_2ndWon l_SvGms  \
# 0             4.0          NaN  ...    33.0     20.0       9.0     9.0
# 1             4.0          NaN  ...    46.0     29.0      13.0    11.0
# 2             NaN          NaN  ...    35.0     25.0       7.0    10.0
# 3             NaN            Q  ...    45.0     34.0      18.0    11.0
# 4             4.0          NaN  ...    43.0     28.0      10.0    10.0
# ...           ...          ...  ...     ...      ...       ...     ...
# 2721          NaN          NaN  ...    57.0     38.0      15.0    14.0
# 2722          NaN          NaN  ...    45.0     30.0      14.0    10.0
# 2723          NaN          NaN  ...    43.0     24.0      13.0    10.0
# 2724          NaN          NaN  ...    50.0     34.0      20.0    11.0
# 2725          NaN          NaN  ...    21.0     16.0       7.0     8.0
#
#       l_bpSaved  l_bpFaced  winner_rank winner_rank_points loser_rank  \
# 0           1.0        5.0         35.0             1518.0      119.0
# 1           3.0        5.0         35.0             1518.0      789.0
# 2           2.0        6.0        119.0              566.0       74.0
# 3           9.0       11.0        789.0               22.0      101.0
# 4           7.0       10.0         35.0             1518.0      293.0
# ...         ...        ...          ...                ...        ...
# 2721        5.0       11.0        905.0               16.0     1136.0
# 2722       10.0       13.0        905.0               16.0      767.0
# 2723        5.0       11.0       1136.0                8.0     1546.0
# 2724        6.0        9.0        170.0              427.0      671.0
# 2725        2.0        7.0        176.0              408.0      196.0
#
#      loser_rank_points
# 0                566.0
# 1                 22.0
# 2                877.0
# 3                733.0
# 4                171.0
# ...                ...
# 2721               8.0
# 2722              27.0
# 2723               2.0
# 2724              38.0
# 2725             359.0
#
# [2701 rows x 49 columns]

# %%
dados.duplicated() #identificando duplicados
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2721    False
# 2722    False
# 2723    False
# 2724    False
# 2725    False
# Length: 2701, dtype: bool

# %%
dados.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##EDA

# %%
import sweetviz #biblioteca para análise exploratória

# %%
eda = sweetviz.analyze(dados)  # eda = exploratory data analysis
eda.show_html()
# Out:
# Done! Use 'show' commands to display/save.   |██████████| [100%]   00:03 -> (00:00 left)
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# ##Correlação

# %%
mask = np.triu(np.ones_like(dados.corr(), dtype=bool)) #na correlação de Pearson, o valor 1 é a correlação direta perfeita; -1 é correlação negativa perfeita e valores próximos de zero indicam a falta de existência ou dificuldade de estabelecer correlação

# %%
plt.figure(figsize=(20,20))
sns.heatmap(dados.corr(), mask=mask, square = True, annot=True, vmin=-1, vmax=1)
plt.show()

# %% [markdown]
# #Exercícios

# %%
#1. Importe os dados de um arquivo CSV com informações de filmes da Marvel, que está disponível em: https://www.kaggle.com/rachit239/mcu-complete-dataset
filmes = pd.read_csv('semana 4_mcu dataset.csv')

# %%
filmes.head(5)
# Out:
#                                  Name US release Date         Director  \
# 0                            Iron Man     May 2, 2008      Jon Favreau
# 1                 The incredible Hulk   June 13, 2008  Louis Leterrier
# 2                          Iron Man 2     May 7, 2010      Jon Favreau
# 3                                Thor     May 6, 2011  Kenneth Branagh
# 4  Captain America: The first Avenger   July 22, 2011     Joe Jhonston
#
#                                   Producer  Duration  \
# 0                 Avi Arad and Kevin Feige   2h 6min
# 1  Avi Arad ,Gale Ann Hurd and Kevin Feige  1h 52min
# 2                              Kevin Feige   2h 4min
# 3                              Kevin Feige  1h 55min
# 4                              Kevin Feige   2h 4min
#
#                          Genre  IMDB rating  metascore  \
# 0   Action , Adventure, Sci-Fi          7.9         79
# 1   Action , Adventure, Sci-Fi          6.6         61
# 2   Action , Adventure, Sci-Fi          7.0         57
# 3  Action , Adventure, Fantasy          7.0         57
# 4   Action , Adventure, Sci-Fi          6.9         66
#
#                                                 Cast        Budget  \
# 0  Robert Downey Jr. , Gweneth Paltrow , Terrence...  $140,000,000
# 1               Edward Norton , Liv Tyler , Tim Roth  $150,000,000
# 2  Robert Downey Jr. , Gweneth Paltrow , Mickey R...  $200,000,000
# 3  Chris Hemsworth , Anthony Hopkins , Natalie Po...  $150,000,000
# 4    Chris Evans ,  Hugo Weaving , Samuel L. Jackson  $140,000,000
#
#   Domestic Gross   Total Gross Opening Gross  Oscar Nomination  Oscar won  \
# 0   $318,604,126  $585,366,247   $98,618,668                 2          0
# 1   $134,806,913  $264,770,996   $55,414,050                 0          0
# 2   $312,433,331  $623,933,331  $128,122,480                 1          0
# 3   $181,030,624  $449,326,618   $65,723,338                 0          0
# 4   $176,654,505  $370,569,774   $65,058,524                 0          0
#
#    Phase
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
#2. Usando a biblioteca Sweetviz, verifique qual foi o valor de orçamento (budget) que aconteceu mais vezes nos filmes da Marvel, e indique qual a porcentagem de vezes que esse valor foi determinado para os filmes.
eda = sweetviz.analyze(filmes)
eda.show_html()

#O valor que apareceu mais vezes de orçamento foi de US$200 milhões e corresponde a 17% dos filmes produzidos
# Out:
# Done! Use 'show' commands to display/save.   |██████████| [100%]   00:00 -> (00:00 left)
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
#3. Usando uma correlação de Pearson, verifique, no database da Marvel, quais são as variáveis que tem maior correlação positiva.
mask = np.triu(np.ones_like(filmes.corr(), dtype=bool))

# %%
plt.figure(figsize=(20,20))
sns.heatmap(filmes.corr(), mask=mask, square = True, annot=True, vmin=-1, vmax=1)
plt.show()

#Conforme é possível ver abaixo, as variáveis com maior correlacão positiva são: Oscar Nomination e Oscar Won. Ou seja, grande parte da vezes quando um filme é indicado ao Oscar, ele vence.

# %%
#4. Entre no Portal Brasileiro de Dados Abertos e baixe o arquivo CSV da Relação de Empreendimentos de Geração (https://dados.gov.br/dataset/relacao-de-empreendimentos-de-geracao). Informe qual é a licença atribuída a esse dado.

# A licença atribuída é OpenData

# %%
#5. Importe somente as primeiras 500 linhas desse arquivo CSV que foi baixado. Observe que como esse arquivo é de origem brasileira, precisaremos utilizar o parâmetro encoding='iso-8859-1' na função read_csv do pandas.

dados_abertos=pd.read_csv("semana 4_EmpreendimentoOperacao.csv",sep=',', nrows=500, encoding='iso-8859-1')

# %%
dados_abertos.head(5)
# Out:
#                   codCEG  codNucleoCEG nomEmpreendimento          datOperacao  \
# 0  UHE.PH.RS.000012-4.01            12      14 de Julho   25/12/2008 00:00:00
# 1  UTE.PE.SC.029920-0.01         29920     29 de Outubro  07/10/2008 00:00:00
# 2  UTE.PE.MG.032686-0.01         32686     300KVA SCANIA  01/06/2013 00:00:00
# 3  UTE.PE.SP.028642-7.01         28642   3M Itapetininga  12/06/2002 00:00:00
# 4  UTE.PE.SP.028919-1.01         28919         3M Sumaré  01/10/2001 00:00:00
#
#   sigTipoGeracao  mdaPotenciaOutorgadakW  mdaPotenciaFiscalizadakW  \
# 0            UHE                100000.0                      47.5
# 1            UTE                    62.0                       0.0
# 2            UTE                   240.0                       0.0
# 3            UTE                  3840.0                       0.0
# 4            UTE                  6400.0                       0.0
#
#   sigDestinoEnergia dscOrigemCombustivel        nomFonteNivel1  \
# 0               PIE              Hídrica  Potencial hidráulico
# 1               REG               Fóssil              Petróleo
# 2               REG               Fóssil              Petróleo
# 3               REG               Fóssil              Petróleo
# 4               APE               Fóssil              Petróleo
#
#          nomFonteNivel2                        dscParticipacaoProprietario  \
# 0  Potencial hidráulico    100.00% para COMPANHIA ENERGÉTICA RIO DAS ANTAS
# 1           Óleo Diesel   100.00% para Condomínio Residencial 29 de Out...
# 2           Óleo Diesel             100.00% para Mineração Curimbaba Ltda.
# 3           Óleo Diesel                     100.00% para 3M do Brasil Ltda
# 4           Óleo Diesel                     100.00% para 3M do Brasil Ltda
#
#                                         dscMunicipio  mesReferencia  \
# 0   Bento Gonçalves - RS - CodIbge: 4302105 / Cot...             12
# 1             Jaraguá do Sul - SC - CodIbge: 4208906             12
# 2            Poços de Caldas - MG - CodIbge: 3151800             12
# 3               Itapetininga - SP - CodIbge: 3522307             12
# 4                     Sumaré - SP - CodIbge: 3552403             12
#
#    anoReferencia     dthProcessamento
# 0           2021  27/12/2021 00:00:00
# 1           2021  27/12/2021 00:00:00
# 2           2021  27/12/2021 00:00:00
# 3           2021  27/12/2021 00:00:00
# 4           2021  27/12/2021 00:00:00

# %%
#6. Com os dados de Empreendimentos de Geração, indique qual é o atributo que mais tem valores nulos e elimine-o.

dados_abertos.isnull().sum()
# Out:
# codCEG                           0
# codNucleoCEG                     0
# nomEmpreendimento                0
# datOperacao                     10
# sigTipoGeracao                   0
# mdaPotenciaOutorgadakW           0
# mdaPotenciaFiscalizadakW       255
# sigDestinoEnergia                0
# dscOrigemCombustivel             0
# nomFonteNivel1                   0
# nomFonteNivel2                   0
# dscParticipacaoProprietario      3
# dscMunicipio                     2
# mesReferencia                    0
# anoReferencia                    0
# dthProcessamento                 0
# dtype: int64

# %%
del dados_abertos['mdaPotenciaFiscalizadakW']
dados_abertos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   codCEG                       500 non-null    object
#  1   codNucleoCEG                 500 non-null    int64
#  2   nomEmpreendimento            500 non-null    object
#  3   datOperacao                  490 non-null    object
#  4   sigTipoGeracao               500 non-null    object
#  5   mdaPotenciaOutorgadakW       500 non-null    float64
#  6   sigDestinoEnergia            500 non-null    object
#  7   dscOrigemCombustivel         500 non-null    object
#  8   nomFonteNivel1               500 non-null    object
#  9   nomFonteNivel2               500 non-null    object
#  10  dscParticipacaoProprietario  497 non-null    object
#  11  dscMunicipio                 498 non-null    object
#  12  mesReferencia                500 non-null    int64
#  13  anoReferencia                500 non-null    int64
#  14  dthProcessamento             500 non-null    object
# dtypes: float64(1), int64(3), object(11)
# memory usage: 58.7+ KB

# %%
#7.  Com os dados de Empreendimentos de Geração, indique qual é o atributo que tem valores nulos na menor quantidade e elimine as linhas que tem esses atributos com valor nulo.

dados_abertos.shape[0]
# Out:
# 500

# %%
dados_abertos.dropna(subset=['dscMunicipio'], inplace=True)

# %%
dados_abertos.shape[0]
# Out:
# 498

# %%
#8. Com os dados de Empreendimentos de Geração, crie uma nova coluna chamada “mdaPotenciaOutorgadaMW”, baseada na coluna “mdaPotenciaOutorgadakW”. Observe que a nova coluna é em Megawatt e a anterior Kilowatt.

dados_abertos['mdaPotenciaOutorgadaMW'] = dados_abertos['mdaPotenciaOutorgadakW']/1000

# %%
dados_abertos.head(5)
# Out:
#                   codCEG  codNucleoCEG nomEmpreendimento          datOperacao  \
# 0  UHE.PH.RS.000012-4.01            12      14 de Julho   25/12/2008 00:00:00
# 1  UTE.PE.SC.029920-0.01         29920     29 de Outubro  07/10/2008 00:00:00
# 2  UTE.PE.MG.032686-0.01         32686     300KVA SCANIA  01/06/2013 00:00:00
# 3  UTE.PE.SP.028642-7.01         28642   3M Itapetininga  12/06/2002 00:00:00
# 4  UTE.PE.SP.028919-1.01         28919         3M Sumaré  01/10/2001 00:00:00
#
#   sigTipoGeracao  mdaPotenciaOutorgadakW sigDestinoEnergia  \
# 0            UHE                100000.0               PIE
# 1            UTE                    62.0               REG
# 2            UTE                   240.0               REG
# 3            UTE                  3840.0               REG
# 4            UTE                  6400.0               APE
#
#   dscOrigemCombustivel        nomFonteNivel1        nomFonteNivel2  \
# 0              Hídrica  Potencial hidráulico  Potencial hidráulico
# 1               Fóssil              Petróleo           Óleo Diesel
# 2               Fóssil              Petróleo           Óleo Diesel
# 3               Fóssil              Petróleo           Óleo Diesel
# 4               Fóssil              Petróleo           Óleo Diesel
#
#                          dscParticipacaoProprietario  \
# 0    100.00% para COMPANHIA ENERGÉTICA RIO DAS ANTAS
# 1   100.00% para Condomínio Residencial 29 de Out...
# 2             100.00% para Mineração Curimbaba Ltda.
# 3                     100.00% para 3M do Brasil Ltda
# 4                     100.00% para 3M do Brasil Ltda
#
#                                         dscMunicipio  mesReferencia  \
# 0   Bento Gonçalves - RS - CodIbge: 4302105 / Cot...             12
# 1             Jaraguá do Sul - SC - CodIbge: 4208906             12
# 2            Poços de Caldas - MG - CodIbge: 3151800             12
# 3               Itapetininga - SP - CodIbge: 3522307             12
# 4                     Sumaré - SP - CodIbge: 3552403             12
#
#    anoReferencia     dthProcessamento  mdaPotenciaOutorgadaMW
# 0           2021  27/12/2021 00:00:00                 100.000
# 1           2021  27/12/2021 00:00:00                   0.062
# 2           2021  27/12/2021 00:00:00                   0.240
# 3           2021  27/12/2021 00:00:00                   3.840
# 4           2021  27/12/2021 00:00:00                   6.400

# %%
#9. Com os dados de Empreendimentos de Geração, na coluna datOperação, deixe apenas a data nos valores, eliminando a informação sobre horas.

dados_abertos['datOperacao'] = dados_abertos['datOperacao'].str.replace(' 00:00:00','')

# %%
dados_abertos['datOperacao'].head(5)
# Out:
# 0    25/12/2008
# 1    07/10/2008
# 2    01/06/2013
# 3    12/06/2002
# 4    01/10/2001
# Name: datOperacao, dtype: object
